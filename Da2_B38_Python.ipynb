# %%
getting Started

# %%
into in python variabls

# %%
Rules of variables

# %%
no sapce between variable name

# %%
firstname = 'anwarul'
print(firstname)
# Out:
# anwarul

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aa64a3f43f47> in <module>
# ----> 1 print(firstname)
#
# NameError: name 'firstname' is not defined

# %%
ss='ssssssssss'
print(ss)
# Out:
# ssssssssss

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3a01f94a1835> in <module>
# ----> 1 print(ss)
#
# NameError: name 'ss' is not defined

# %%
1. no name space while declaring variable
2. no specialr characters include in valriable
3. variable name should not start with number- --@,$#%& etc

# %%
Introduction to Data Types in python
1. string str
2. Number - integrgs(int) , float(float)
3. List (list)
4. tuple(tuple)
5. dictionaries (dic)

# %%
classification of datatypes

data types are broadly classified in 2 categ
1. Mutable datatype - which can be edit later once it has been declared - flexibale 
2. immutable datatype - which can not alter or edit once we have declred -- fixed

# %%
inntroduction to string data type
overview and defincation : a string is nothing but s series of characters enclosed in quotes
    classification: It is classified as an immmutable datatype
        
        How to define the string ...?
        
        3 possible way to declatred as below
        1. single quotes
        2. double quote
        3. triple quotes
        
        we can use any one of them
        
        name1='Anwarul'
        name2="Anwarul"
        name3 = """Anwarul"""
# Out:
#   File "<ipython-input-10-96155e3655da>", line 1
#     inntroduction to string data type
#                   ^
# SyntaxError: invalid syntax

# %%
  name1='Anwarul'
    print(name1)
# Out:
#   File "<ipython-input-24-b039cd9ea56b>", line 2
#     print(name1)
#     ^
# IndentationError: unexpected indent

# %%
  name2="Anwarul"
    print(name2)
# Out:
#   File "<ipython-input-25-0903f1142545>", line 2
#     print(name2)
#     ^
# IndentationError: unexpected indent

# %%
 name3 = """Anwarul"""
        
   print(name3)
# Out:
#   File "<ipython-input-27-98d6904adec4>", line 3
#     print(name3)
#     ^
# IndentationError: unexpected indent

# %%
introduction to string method:
    1. type method - it is used for nowing the  datatypes of the variable defined

# %%
type(name1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-971b0bf044ae> in <module>
# ----> 1 type(name1)
#
# NameError: name 'name1' is not defined

# %%
type(name1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-971b0bf044ae> in <module>
# ----> 1 type(name1)
#
# NameError: name 'name1' is not defined

# %%
type(name1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-971b0bf044ae> in <module>
# ----> 1 type(name1)
#
# NameError: name 'name1' is not defined

# %%
# comment 
print('hello')
# Out:
# hello

# %%
name4='Anwarul'
print(name4)
# Out:
# Anwarul

# %%
type(name4)
# Out:
# str
